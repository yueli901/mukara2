# %%
from evaluate_log import extract_metrics
import matplotlib.pyplot as plt

# Load and preprocess log data
df = extract_metrics('logs/training_log.log')[:]

# Define custom colors
train_color = (31/255, 119/255, 180/255)  # Blue for training
test_color = (214/255, 39/255, 40/255)    # Red for testing

# Define x-axis values
x_values = df['epoch'] + df['sensor'] / (max(df['sensor']) + 1)

# Create subplots in one row
fig, axes = plt.subplots(1, 5, figsize=(20, 4))

# Total Loss
axes[0].plot(x_values, df['train_total_loss'], label='Train', color=train_color)
axes[0].plot(x_values, df['valid_total_loss'], label='Test', color=test_color)
axes[0].set_title('Total Loss')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Loss')
axes[0].legend()

# Traffic Loss (MGEH)
axes[1].plot(x_values, df['train_geh'], label='Train', color=train_color)
axes[1].plot(x_values, df['valid_geh'], label='Test', color=test_color)
axes[1].set_title('Traffic Loss (MGEH)')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('MGEH')
axes[1].legend()

# Compactness Loss
axes[2].plot(x_values, df['train_compactness'], label='Train', color=train_color)
axes[2].plot(x_values, df['valid_compactness'], label='Test', color=test_color)
axes[2].set_title('Compactness Loss')
axes[2].set_xlabel('Epochs')
axes[2].set_ylabel('Loss')
axes[2].legend()

# Separation Loss
axes[3].plot(x_values, df['train_separation'], label='Train', color=train_color)
axes[3].plot(x_values, df['valid_separation'], label='Test', color=test_color)
axes[3].set_title('Separation Loss')
axes[3].set_xlabel('Epochs')
axes[3].set_ylabel('Loss')
axes[3].legend()

# Balance Loss
axes[4].plot(x_values, df['train_balance'], label='Train', color=train_color)
axes[4].plot(x_values, df['valid_balance'], label='Test', color=test_color)
axes[4].set_title('Balance Loss')
axes[4].set_xlabel('Epochs')
axes[4].set_ylabel('Loss')
axes[4].legend()

# Adjust layout and save
plt.tight_layout()
plt.savefig('learning_curve.png')
plt.show()

# %%
df
# Out:
#    epoch  sensor  train_total_loss  train_geh  train_mae  train_compactness  \
# 3      0    2000           116.820    116.820  19067.307          21616.082
# 4      0    2500           131.245    131.245  22056.846          21061.870
# 5      0    3000            87.078     87.078  12813.529          18949.514
# 6      0    3500           111.707    111.707  16630.119          20316.007
# 7      0    4000           119.435    119.435  20646.287          21661.879
# 8      0    4500           109.245    109.245  18201.673          19741.811
# 9      0    5000           124.796    124.796  20845.341          21225.358
#
#    train_separation  train_balance  valid_total_loss  valid_geh  valid_mae  \
# 3           109.660    2792987.882           109.443    109.443  17670.530
# 4           105.469    2753654.851           139.122    139.122  23960.733
# 5           100.564    2461883.188           101.204    101.204  16704.921
# 6            95.970    2490892.685            98.595     98.595  16377.195
# 7            91.786    2480251.555           105.032    105.032  17116.071
# 8            88.616    2046602.721            98.217     98.217  15576.364
# 9            86.260    1718156.100           106.005    106.005  17256.507
#
#    valid_compactness  valid_separation  valid_balance
# 3          21411.794           109.661    2798038.380
# 4          21158.570           105.469    2687507.977
# 5          20825.301           100.564    2666557.118
# 6          19736.693            95.970    2400178.034
# 7          20946.743            91.786    2382163.640
# 8          20044.530            88.616    2167773.305
# 9          19262.948            86.260    1613033.461

# %%
print(min(df['valid_mae']))
print(min(df['valid_geh']))
# Out:
# 15576.364
# 98.217
